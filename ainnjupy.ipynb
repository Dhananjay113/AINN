# %%
print("Jai Jagannath")
# Out:
# Jai Jagannath

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_set = "https://raw.githubusercontent.com/Dhananjay113/AINN/main/dat_small2.csv"

# %%
df = pd.read_csv(data_set)
df.head()
# Out:
#       userName                       major  researchExp  industryExp  \
# 0       143saf         Systems and Control            0           18
# 1   7790ashish   Manufacturing Engineering            0            0
# 2         AB25  (MIS / MSIM / MSIS / MSIT)            0           66
# 3     abhijitg                         NaN            0            0
# 4  abhijitgang                         MIS            0            0
#
#   specialization  toeflScore program                 department  toeflEssay  \
# 0       Robotics       112.0      MS  Instrumentation & Control        26.0
# 1            NaN         NaN      MS                          0         NaN
# 2            NaN        94.0      MS       Computer Engineering        21.0
# 3            NaN         NaN     NaN                          0         NaN
# 4            NaN        81.0      MS                   computer         NaN
#
#    internExp  ...  termAndYear  confPubs                    ugCollege  gmatA  \
# ...

# %%
df.shape
# Out:
# (200, 26)

# %%
#Descripitive analysis
df.describe()
# Out:
#        researchExp  industryExp   toeflScore  toeflEssay   internExp  \
# count   200.000000   200.000000   177.000000   50.000000  200.000000
# mean      0.185000     3.740000   105.920904   23.150000    0.520000
# std       1.523938    10.603043    74.731295    7.530381    2.039706
# min       0.000000     0.000000     0.000000    3.000000    0.000000
# 25%       0.000000     0.000000    94.000000   22.000000    0.000000
# 50%       0.000000     0.000000    99.000000   25.500000    0.000000
# 75%       0.000000     0.000000   106.000000   27.750000    0.000000
# max      15.000000    66.000000  1040.000000   30.000000   15.000000
#
#              greV         greQ  journalPubs        greA  topperCgpa  \
# count  191.000000   192.000000   199.000000  186.000000  200.000000
# mean   260.874346   369.197917     0.060302   10.739247   40.943050
# std    168.535596   293.958027     0.528369   72.212191   38.122247
# min     25.000000    41.000000     0.000000    2.000000    0.000000
# ...

# %%
# Scatter Plot

plt.figure(figsize=(20,10))
sns.scatterplot(data=df,x='cgpa',y='topperCgpa')
plt.show()

# %%
from sklearn.cluster import KMeans

# %%
#features
Xfeatures = df[['cgpa','topperCgpa','greA']]

# %%
#Model
model = KMeans(n_cluters=3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [15], line 2
#       1 #Model
# ----> 2 model = KMeans(n_cluters=3)
#
# TypeError: KMeans.__init__() got an unexpected keyword argument 'n_cluters'

# %%
model.fit(Xfeatures)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [14], line 1
# ----> 1 model.fit(Xfeatures)
#
# NameError: name 'model' is not defined
